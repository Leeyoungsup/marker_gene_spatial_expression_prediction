# %% [markdown]
# # Visium Data Preprocessing (MPP=0.5 기준)
#
# Visium 기술만 대상으로
# MPP=0.5 µm/pixel (20x) 기준 grid 패치 추출 + **3-head label** 생성
#
# ### 3-Head Label Design
# - **Head A: Presence** — gene이 패치에 존재하는지 (binary, BCE loss)
# - **Head B: Expression** — 존재 시 조건부 발현량 (log1p normalized, masked Gaussian NLL)
# - **Head C: Uncertainty** — 예측 불확실성 (학습 시 자동 학습, label 불필요)

# %%
# ===== 1. 설정 및 라이브러리 =====
from glob import glob
import os
import numpy as np
import pandas as pd
import openslide
from PIL import Image
import matplotlib.pyplot as plt
from tqdm import tqdm
import anndata
import warnings
warnings.filterwarnings('ignore', message='Variable names are not unique')

def create_dir(path):
    os.makedirs(path, exist_ok=True)

# 하이퍼파라미터
TARGET_MPP = 0.5        # 20x 해상도 (µm/pixel)
CONTEXT_SCALE = 4       # 5x context = 4x wider
PATCH_SIZE = 512        # 패치 크기 (pixels)
MIN_TRANSCRIPTS = 10    # 패치 내 최소 transcript 수
MIN_GENES = 10000       # 슬라이드 최소 gene 수 (이하 제외)

# 대상 기술
TARGET_TECHS = ['Visium','Visium HD', "Visium HD 3'"]

print(f'TARGET_MPP: {TARGET_MPP} µm/pixel')
print(f'PATCH_SIZE: {PATCH_SIZE}')
print(f'CONTEXT_SCALE: {CONTEXT_SCALE} (5x)')
print(f'MIN_TRANSCRIPTS: {MIN_TRANSCRIPTS}')
print(f'MIN_GENES: {MIN_GENES}')
print(f'TARGET_TECHS: {TARGET_TECHS}')
# Out:
# TARGET_MPP: 0.5 µm/pixel
# PATCH_SIZE: 512
# CONTEXT_SCALE: 4 (5x)
# MIN_TRANSCRIPTS: 10
# MIN_GENES: 10000
# TARGET_TECHS: ['Visium', 'Visium HD', "Visium HD 3'"]

# %%
# ===== 2. 데이터 경로 및 저장 디렉토리 생성 =====
data_path = '../../data/spatialTranscriptome/'
parquet_path = f'{data_path}transcripts/'  # parquet transcript 파일 경로
save_base = '../../data/visium_marker_gene_spatial_expression'

meta_df = pd.read_csv(f'{data_path}meta_df_homo_sapiens.csv')
print(f'Total slides in metadata: {len(meta_df)}')

# 대상 기술만 필터링
target_df = meta_df[meta_df['st_technology'].isin(TARGET_TECHS)].reset_index(drop=True)
print(f'Target slides ({TARGET_TECHS}): {len(target_df)}')
print(target_df['st_technology'].value_counts())

# parquet 파일 존재 여부 확인
parquet_available = []
for idx in range(len(target_df)):
    sid = target_df.iloc[idx]['id']
    pq_file = f'{parquet_path}{sid}_transcripts.parquet'
    parquet_available.append(os.path.exists(pq_file))
target_df['has_parquet'] = parquet_available
print(f'Slides with parquet: {sum(parquet_available)} / {len(target_df)}')

# organ 목록
organs = target_df['organ'].unique().tolist()
print(f'Organs: {organs}')

# 저장 디렉토리 생성
for o in organs:
    for t in TARGET_TECHS:
        create_dir(f'{save_base}/image/{t}/{o}')
        create_dir(f'{save_base}/image_5x/{t}/{o}')
        create_dir(f'{save_base}/label_presence/{t}/{o}')
        create_dir(f'{save_base}/label_expression/{t}/{o}')

print('Directories created.')
# Out:
# Total slides in metadata: 668
# Target slides (['Visium', 'Visium HD', "Visium HD 3'"]): 446
# st_technology
# Visium          421
# Visium HD        21
# Visium HD 3'      4
# Name: count, dtype: int64
# Slides with parquet: 0 / 446
# Organs: ['Ovary', 'Breast', 'Pancreas', 'Lymphoid', 'Prostate', 'Kidney', 'Lung', 'Bowel', 'Heart', 'Brain', 'Cervix', 'Lymph node', 'Skin', 'Bladder', 'Liver', 'Eye', 'Uterus']
# Directories created.

# %%
# ===== 3. 전체 슬라이드 h5ad gene 목록 수집 =====
import re

h5ad_path = f'{data_path}st/'

# 의미없는 gene 필터링 패턴
EXCLUDE_PREFIXES = (
    'MT-',       # 미토콘드리아 유전자
    'RPL', 'RPS', # 리보솜 단백질
    'LINC',      # long intergenic non-coding RNA
    'LOC',       # uncharacterized locus
    'MIR',       # microRNA
    'SNOR', 'SNOU',  # small nucleolar RNA
    'RNA5S', 'RNA18S', 'RNA28S', 'RNA45S',  # ribosomal RNA
    'MTRNR',     # mitochondrial rRNA
)
EXCLUDE_PATTERNS = re.compile(
    r'^(AC\d{6}|AL\d{6}|AP\d{6}|BX\d{6}|CR\d{6})'  # Ensembl novel transcripts
    r'|(-AS\d+$|-IT\d+$|-DT$)'    # antisense / intronic / divergent transcript
    r'|(^ENSG\d+$)'               # Ensembl ID (이름 미해석)
)

def is_meaningful_gene(gene_name):
    """의미 있는 protein-coding gene인지 판별"""
    if gene_name.startswith(EXCLUDE_PREFIXES):
        return False
    if EXCLUDE_PATTERNS.search(gene_name):
        return False
    # 소문자가 포함된 gene name 제외 (orf, pseudogene 등)
    if any(c.islower() for c in gene_name):
        return False
    return True

slide_gene_sets = {}  # sample_id → set of gene names
skipped_low_genes = []

for idx in tqdm(range(len(target_df)), desc='Collecting gene names from h5ad'):
    row = target_df.iloc[idx]
    sample_id = row['id']

    h5ad_file = f'{h5ad_path}{sample_id}.h5ad'
    if not os.path.exists(h5ad_file):
        continue

    adata = anndata.read_h5ad(h5ad_file, backed='r')
    var_names = adata.var_names.tolist()
    adata.file.close()

    # 타입 확인 및 str 변환 (bytes → decode)
    types = set(type(g).__name__ for g in var_names)
    if types != {'str'}:
        print(f'  {sample_id}: gene name types = {types}, converting via decode')
        var_names = [g.decode('utf-8') if isinstance(g, bytes) else str(g) for g in var_names]

    # 의미없는 gene 필터링
    gene_names = {g for g in var_names if is_meaningful_gene(g)}

    if len(gene_names) <= MIN_GENES:
        skipped_low_genes.append((sample_id, len(gene_names)))
        continue

    slide_gene_sets[sample_id] = gene_names

# 필터링 효과 확인 (첫 슬라이드 기준)
if slide_gene_sets:
    first_sid = next(iter(slide_gene_sets))
    adata_tmp = anndata.read_h5ad(f'{h5ad_path}{first_sid}.h5ad', backed='r')
    raw_count = len(adata_tmp.var_names)
    adata_tmp.file.close()
    filtered_count = len(slide_gene_sets[first_sid])
    print(f'\n필터링 예시 ({first_sid}): {raw_count:,} → {filtered_count:,} genes ({raw_count - filtered_count:,}개 제거)')

print(f'\nh5ad 로드 성공: {len(slide_gene_sets)} / {len(target_df)} slides')
print(f'Gene 수 {MIN_GENES}개 이하로 제외: {len(skipped_low_genes)}개')
for sid, n in skipped_low_genes:
    print(f'  {sid}: {n:,} genes')
if slide_gene_sets:
    print(f'Gene 수 범위: {min(len(g) for g in slide_gene_sets.values()):,} ~ {max(len(g) for g in slide_gene_sets.values()):,}')

    all_types = set()
    for genes in slide_gene_sets.values():
        all_types.update(type(g).__name__ for g in genes)
    print(f'Gene name 타입: {all_types}')
# Out:
# Collecting gene names from h5ad: 100%|██████████| 446/446 [00:27<00:00, 16.24it/s]
# 필터링 예시 (TENX185): 18,132 → 17,834 genes (298개 제거)
#
# h5ad 로드 성공: 385 / 446 slides
# Gene 수 10000개 이하로 제외: 61개
#   MISC142: 0 genes
#   MISC141: 0 genes
#   MISC140: 0 genes
#   MISC139: 0 genes
#   MISC138: 0 genes
#   MISC136: 0 genes
#   MISC135: 0 genes
#   MISC134: 0 genes
#   MISC133: 0 genes
#   MISC132: 0 genes
#   MISC131: 0 genes
#   MISC130: 0 genes
#   MISC129: 0 genes
#   MISC128: 0 genes
#   MISC127: 0 genes
#   MISC126: 0 genes
#   MISC125: 0 genes
#   MISC124: 0 genes
#   MISC123: 0 genes
#   MISC122: 0 genes
#   MISC121: 0 genes
#   MISC120: 0 genes
#   MISC119: 0 genes
#   MISC118: 0 genes
#   MISC117: 0 genes
#   MISC116: 0 genes
#   MISC115: 0 genes
#   MISC114: 0 genes
#   MISC113: 0 genes
#   MISC112: 0 genes
#   MISC111: 0 genes
#   MISC110: 0 genes
#   MISC109: 0 genes
#   MISC108: 0 genes
#   MISC107: 0 genes
#   MISC106: 0 genes
#   MISC105: 0 genes
#   MISC104: 0 genes
#   MISC103: 0 genes
#   MISC102: 0 genes
#   MISC101: 0 genes
#   TENX56: 1,184 genes
#   TENX30: 1,245 genes
#   TENX28: 1,138 genes
#   TENX23: 1,056 genes
#   MEND52: 0 genes
#   NCBI576: 7 genes
#   NCBI575: 7 genes
#   NCBI574: 7 genes
#   NCBI573: 7 genes
#   NCBI821: 7 genes
#   NCBI820: 7 genes
#   NCBI819: 7 genes
#   NCBI818: 7 genes
#   NCBI817: 7 genes
#   NCBI816: 7 genes
#   NCBI815: 7 genes
#   NCBI814: 7 genes
#   NCBI813: 7 genes
#   NCBI812: 7 genes
#   NCBI811: 7 genes
# Gene 수 범위: 17,516 ~ 21,720
# Gene name 타입: {'str'}

# %%
# ===== 4. 85% 이상 슬라이드에 존재하는 gene 추출 =====
from collections import Counter

COVERAGE_THRESHOLD = 0.85  # 85% 이상

# gene별 등장 슬라이드 수 카운트
gene_counter = Counter()
for genes in slide_gene_sets.values():
    gene_counter.update(genes)

n_slides = len(slide_gene_sets)
min_slides = int(np.ceil(n_slides * COVERAGE_THRESHOLD))

common_genes = {g for g, cnt in gene_counter.items() if cnt >= min_slides}
common_genes_sorted = sorted(common_genes)

print(f'전체 슬라이드 수: {n_slides}')
print(f'기준: {COVERAGE_THRESHOLD*100:.0f}% 이상 = {min_slides}개 슬라이드 이상 보유')
print(f'선택된 gene 수: {len(common_genes):,}')
print(f'\n선택된 gene 목록 (처음 50개):')
for i, g in enumerate(common_genes_sorted[:50]):
    cnt = gene_counter[g]
    print(f'  [{i:>4d}] {g:>15s}  ({cnt}/{n_slides} slides, {cnt/n_slides*100:.1f}%)')
if len(common_genes_sorted) > 50:
    print(f'  ... 외 {len(common_genes_sorted) - 50}개')

# 커버리지별 gene 수 분포
print(f'\n커버리지별 gene 수:')
for pct in [100, 95, 90, 85, 80, 70, 50]:
    threshold = int(np.ceil(n_slides * pct / 100))
    n_genes = sum(1 for cnt in gene_counter.values() if cnt >= threshold)
    print(f'  {pct:>3d}% ({threshold:>3d}+ slides): {n_genes:,} genes')

# 선택된 common_genes를 보유하지 않는 슬라이드 확인
print(f'\n===== 버려지는 슬라이드 (common_genes 중 누락 있는 슬라이드) =====')
dropped_slides = []
for sid, genes in slide_gene_sets.items():
    missing = common_genes - genes
    if missing:
        dropped_slides.append((sid, len(missing), sorted(missing)))

print(f'common_genes 완전 보유: {n_slides - len(dropped_slides)} / {n_slides} slides')
print(f'누락 있는 슬라이드: {len(dropped_slides)}개')
for sid, n_miss, miss_list in sorted(dropped_slides, key=lambda x: -x[1]):
    print(f'  {sid}: {n_miss}개 누락 — {miss_list[:10]}{"..." if n_miss > 10 else ""}')
# Out:
# 전체 슬라이드 수: 385
# 기준: 85% 이상 = 328개 슬라이드 이상 보유
# 선택된 gene 수: 17,928
#
# 선택된 gene 목록 (처음 50개):
#   [   0]            A1BG  (351/385 slides, 91.2%)
#   [   1]            A1CF  (385/385 slides, 100.0%)
#   [   2]             A2M  (385/385 slides, 100.0%)
#   [   3]           A2ML1  (384/385 slides, 99.7%)
#   [   4]         A3GALT2  (384/385 slides, 99.7%)
#   [   5]          A4GALT  (385/385 slides, 100.0%)
#   [   6]           A4GNT  (384/385 slides, 99.7%)
#   [   7]            AAAS  (385/385 slides, 100.0%)
#   [   8]            AACS  (385/385 slides, 100.0%)
#   [   9]           AADAC  (385/385 slides, 100.0%)
#   [  10]         AADACL2  (383/385 slides, 99.5%)
#   [  11]         AADACL3  (385/385 slides, 100.0%)
#   [  12]         AADACL4  (385/385 slides, 100.0%)
#   [  13]           AADAT  (385/385 slides, 100.0%)
#   [  14]           AAGAB  (385/385 slides, 100.0%)
#   [  15]            AAK1  (385/385 slides, 100.0%)
#   [  16]           AAMDC  (385/385 slides, 100.0%)
#   [  17]            AAMP  (385/385 slides, 100.0%)
#   [  18]           AANAT  (384/385 slides, 99.7%)
#   [  19]            AAR2  (385/385 slides, 100.0%)
#   [  20]            AARD  (381/385 slides, 99.0%)
#   [  21]           AARS2  (385/385 slides, 100.0%)
#   [  22]          AARSD1  (385/385 slides, 100.0%)
#   [  23]           AASDH  (385/385 slides, 100.0%)
#   [  24]        AASDHPPT  (385/385 slides, 100.0%)
#   [  25]            AASS  (385/385 slides, 100.0%)
#   [  26]            AATF  (385/385 slides, 100.0%)
#   [  27]            AATK  (385/385 slides, 100.0%)
#   [  28]            ABAT  (385/385 slides, 100.0%)
#   [  29]           ABCA1  (385/385 slides, 100.0%)
#   [  30]          ABCA10  (384/385 slides, 99.7%)
#   [  31]          ABCA12  (385/385 slides, 100.0%)
#   [  32]          ABCA13  (385/385 slides, 100.0%)
#   [  33]           ABCA2  (385/385 slides, 100.0%)
#   [  34]           ABCA3  (385/385 slides, 100.0%)
#   [  35]           ABCA4  (385/385 slides, 100.0%)
#   [  36]           ABCA5  (385/385 slides, 100.0%)
#   [  37]           ABCA6  (385/385 slides, 100.0%)
#   [  38]           ABCA7  (385/385 slides, 100.0%)
#   [  39]           ABCA8  (385/385 slides, 100.0%)
#   [  40]           ABCA9  (385/385 slides, 100.0%)
#   [  41]           ABCB1  (385/385 slides, 100.0%)
#   [  42]          ABCB10  (338/385 slides, 87.8%)
#   [  43]          ABCB11  (385/385 slides, 100.0%)
#   [  44]           ABCB4  (385/385 slides, 100.0%)
#   [  45]           ABCB5  (385/385 slides, 100.0%)
#   [  46]           ABCB6  (385/385 slides, 100.0%)
#   [  47]           ABCB7  (385/385 slides, 100.0%)
#   [  48]           ABCB8  (385/385 slides, 100.0%)
#   [  49]           ABCB9  (385/385 slides, 100.0%)
#   ... 외 17878개
#
# 커버리지별 gene 수:
#   100% (385+ slides): 14,418 genes
#    95% (366+ slides): 16,661 genes
#    90% (347+ slides): 17,150 genes
#    85% (328+ slides): 17,928 genes
#    80% (308+ slides): 18,092 genes
#    70% (270+ slides): 18,671 genes
#    50% (193+ slides): 19,734 genes
#
# ===== 버려지는 슬라이드 (common_genes 중 누락 있는 슬라이드) =====
# common_genes 완전 보유: 246 / 385 slides
# 누락 있는 슬라이드: 139개
#   MISC44: 859개 누락 — ['A2ML1', 'AADACL2', 'ABHD16B', 'ACKR4', 'ACSM2A', 'ACTBL2', 'ACTL7B', 'ACTRT1', 'ADAM18', 'ADAM2']...
#   NCBI855: 666개 누락 — ['ABCB10', 'ACSM2A', 'ACSM2B', 'ACTA1', 'ACTBL2', 'ACTG1', 'ACTL10', 'ACTR2', 'ADAM21', 'ADAT2']...
#   NCBI854: 666개 누락 — ['ABCB10', 'ACSM2A', 'ACSM2B', 'ACTA1', 'ACTBL2', 'ACTG1', 'ACTL10', 'ACTR2', 'ADAM21', 'ADAT2']...
#   MISC16: 665개 누락 — ['ABCB10', 'ACSM2A', 'ACSM2B', 'ACTA1', 'ACTBL2', 'ACTG1', 'ACTL10', 'ACTR2', 'ADAM21', 'ADAT2']...
#   MISC15: 665개 누락 — ['ABCB10', 'ACSM2A', 'ACSM2B', 'ACTA1', 'ACTBL2', 'ACTG1', 'ACTL10', 'ACTR2', 'ADAM21', 'ADAT2']...
#   MISC14: 665개 누락 — ['ABCB10', 'ACSM2A', 'ACSM2B', 'ACTA1', 'ACTBL2', 'ACTG1', 'ACTL10', 'ACTR2', 'ADAM21', 'ADAT2']...
#   MISC13: 665개 누락 — ['ABCB10', 'ACSM2A', 'ACSM2B', 'ACTA1', 'ACTBL2', 'ACTG1', 'ACTL10', 'ACTR2', 'ADAM21', 'ADAT2']...
#   TENX51: 664개 누락 — ['ABCB10', 'ACSM2A', 'ACSM2B', 'ACTA1', 'ACTBL2', 'ACTG1', 'ACTL10', 'ACTR2', 'ADAM21', 'ADAT2']...
#   TENX50: 664개 누락 — ['ABCB10', 'ACSM2A', 'ACSM2B', 'ACTA1', 'ACTBL2', 'ACTG1', 'ACTL10', 'ACTR2', 'ADAM21', 'ADAT2']...
#   TENX49: 664개 누락 — ['ABCB10', 'ACSM2A', 'ACSM2B', 'ACTA1', 'ACTBL2', 'ACTG1', 'ACTL10', 'ACTR2', 'ADAM21', 'ADAT2']...
#   TENX46: 664개 누락 — ['ABCB10', 'ACSM2A', 'ACSM2B', 'ACTA1', 'ACTBL2', 'ACTG1', 'ACTL10', 'ACTR2', 'ADAM21', 'ADAT2']...
#   TENX41: 664개 누락 — ['ABCB10', 'ACSM2A', 'ACSM2B', 'ACTA1', 'ACTBL2', 'ACTG1', 'ACTL10', 'ACTR2', 'ADAM21', 'ADAT2']...
#   TENX40: 664개 누락 — ['ABCB10', 'ACSM2A', 'ACSM2B', 'ACTA1', 'ACTBL2', 'ACTG1', 'ACTL10', 'ACTR2', 'ADAM21', 'ADAT2']...
#   TENX39: 664개 누락 — ['ABCB10', 'ACSM2A', 'ACSM2B', 'ACTA1', 'ACTBL2', 'ACTG1', 'ACTL10', 'ACTR2', 'ADAM21', 'ADAT2']...
#   INT35: 664개 누락 — ['ABCB10', 'ACSM2A', 'ACSM2B', 'ACTA1', 'ACTBL2', 'ACTG1', 'ACTL10', 'ACTR2', 'ADAM21', 'ADAT2']...
#   INT28: 664개 누락 — ['ABCB10', 'ACSM2A', 'ACSM2B', 'ACTA1', 'ACTBL2', 'ACTG1', 'ACTL10', 'ACTR2', 'ADAM21', 'ADAT2']...
#   INT27: 664개 누락 — ['ABCB10', 'ACSM2A', 'ACSM2B', 'ACTA1', 'ACTBL2', 'ACTG1', 'ACTL10', 'ACTR2', 'ADAM21', 'ADAT2']...
#   INT26: 664개 누락 — ['ABCB10', 'ACSM2A', 'ACSM2B', 'ACTA1', 'ACTBL2', 'ACTG1', 'ACTL10', 'ACTR2', 'ADAM21', 'ADAT2']...
#   INT25: 664개 누락 — ['ABCB10', 'ACSM2A', 'ACSM2B', 'ACTA1', 'ACTBL2', 'ACTG1', 'ACTL10', 'ACTR2', 'ADAM21', 'ADAT2']...
#   INT24: 664개 누락 — ['ABCB10', 'ACSM2A', 'ACSM2B', 'ACTA1', 'ACTBL2', 'ACTG1', 'ACTL10', 'ACTR2', 'ADAM21', 'ADAT2']...
#   INT23: 664개 누락 — ['ABCB10', 'ACSM2A', 'ACSM2B', 'ACTA1', 'ACTBL2', 'ACTG1', 'ACTL10', 'ACTR2', 'ADAM21', 'ADAT2']...
#   INT22: 664개 누락 — ['ABCB10', 'ACSM2A', 'ACSM2B', 'ACTA1', 'ACTBL2', 'ACTG1', 'ACTL10', 'ACTR2', 'ADAM21', 'ADAT2']...
#   INT21: 664개 누락 — ['ABCB10', 'ACSM2A', 'ACSM2B', 'ACTA1', 'ACTBL2', 'ACTG1', 'ACTL10', 'ACTR2', 'ADAM21', 'ADAT2']...
#   INT20: 664개 누락 — ['ABCB10', 'ACSM2A', 'ACSM2B', 'ACTA1', 'ACTBL2', 'ACTG1', 'ACTL10', 'ACTR2', 'ADAM21', 'ADAT2']...
#   INT19: 664개 누락 — ['ABCB10', 'ACSM2A', 'ACSM2B', 'ACTA1', 'ACTBL2', 'ACTG1', 'ACTL10', 'ACTR2', 'ADAM21', 'ADAT2']...
#   INT18: 664개 누락 — ['ABCB10', 'ACSM2A', 'ACSM2B', 'ACTA1', 'ACTBL2', 'ACTG1', 'ACTL10', 'ACTR2', 'ADAM21', 'ADAT2']...
#   INT17: 664개 누락 — ['ABCB10', 'ACSM2A', 'ACSM2B', 'ACTA1', 'ACTBL2', 'ACTG1', 'ACTL10', 'ACTR2', 'ADAM21', 'ADAT2']...
#   INT16: 664개 누락 — ['ABCB10', 'ACSM2A', 'ACSM2B', 'ACTA1', 'ACTBL2', 'ACTG1', 'ACTL10', 'ACTR2', 'ADAM21', 'ADAT2']...
#   INT15: 664개 누락 — ['ABCB10', 'ACSM2A', 'ACSM2B', 'ACTA1', 'ACTBL2', 'ACTG1', 'ACTL10', 'ACTR2', 'ADAM21', 'ADAT2']...
#   INT14: 664개 누락 — ['ABCB10', 'ACSM2A', 'ACSM2B', 'ACTA1', 'ACTBL2', 'ACTG1', 'ACTL10', 'ACTR2', 'ADAM21', 'ADAT2']...
#   INT13: 664개 누락 — ['ABCB10', 'ACSM2A', 'ACSM2B', 'ACTA1', 'ACTBL2', 'ACTG1', 'ACTL10', 'ACTR2', 'ADAM21', 'ADAT2']...
#   MEND96: 664개 누락 — ['ABCB10', 'ACSM2A', 'ACSM2B', 'ACTA1', 'ACTBL2', 'ACTG1', 'ACTL10', 'ACTR2', 'ADAM21', 'ADAT2']...
#   MEND93: 664개 누락 — ['ABCB10', 'ACSM2A', 'ACSM2B', 'ACTA1', 'ACTBL2', 'ACTG1', 'ACTL10', 'ACTR2', 'ADAM21', 'ADAT2']...
#   MEND92: 664개 누락 — ['ABCB10', 'ACSM2A', 'ACSM2B', 'ACTA1', 'ACTBL2', 'ACTG1', 'ACTL10', 'ACTR2', 'ADAM21', 'ADAT2']...
#   MEND91: 664개 누락 — ['ABCB10', 'ACSM2A', 'ACSM2B', 'ACTA1', 'ACTBL2', 'ACTG1', 'ACTL10', 'ACTR2', 'ADAM21', 'ADAT2']...
#   MEND90: 664개 누락 — ['ABCB10', 'ACSM2A', 'ACSM2B', 'ACTA1', 'ACTBL2', 'ACTG1', 'ACTL10', 'ACTR2', 'ADAM21', 'ADAT2']...
#   MEND89: 664개 누락 — ['ABCB10', 'ACSM2A', 'ACSM2B', 'ACTA1', 'ACTBL2', 'ACTG1', 'ACTL10', 'ACTR2', 'ADAM21', 'ADAT2']...
#   MEND66: 664개 누락 — ['ABCB10', 'ACSM2A', 'ACSM2B', 'ACTA1', 'ACTBL2', 'ACTG1', 'ACTL10', 'ACTR2', 'ADAM21', 'ADAT2']...
#   MEND65: 664개 누락 — ['ABCB10', 'ACSM2A', 'ACSM2B', 'ACTA1', 'ACTBL2', 'ACTG1', 'ACTL10', 'ACTR2', 'ADAM21', 'ADAT2']...
#   MEND64: 664개 누락 — ['ABCB10', 'ACSM2A', 'ACSM2B', 'ACTA1', 'ACTBL2', 'ACTG1', 'ACTL10', 'ACTR2', 'ADAM21', 'ADAT2']...
#   MEND63: 664개 누락 — ['ABCB10', 'ACSM2A', 'ACSM2B', 'ACTA1', 'ACTBL2', 'ACTG1', 'ACTL10', 'ACTR2', 'ADAM21', 'ADAT2']...
#   MEND60: 664개 누락 — ['ABCB10', 'ACSM2A', 'ACSM2B', 'ACTA1', 'ACTBL2', 'ACTG1', 'ACTL10', 'ACTR2', 'ADAM21', 'ADAT2']...
#   MEND59: 664개 누락 — ['ABCB10', 'ACSM2A', 'ACSM2B', 'ACTA1', 'ACTBL2', 'ACTG1', 'ACTL10', 'ACTR2', 'ADAM21', 'ADAT2']...
#   NCBI771: 664개 누락 — ['ABCB10', 'ACSM2A', 'ACSM2B', 'ACTA1', 'ACTBL2', 'ACTG1', 'ACTL10', 'ACTR2', 'ADAM21', 'ADAT2']...
#   NCBI656: 664개 누락 — ['ABCB10', 'ACSM2A', 'ACSM2B', 'ACTA1', 'ACTBL2', 'ACTG1', 'ACTL10', 'ACTR2', 'ADAM21', 'ADAT2']...
#   NCBI655: 664개 누락 — ['ABCB10', 'ACSM2A', 'ACSM2B', 'ACTA1', 'ACTBL2', 'ACTG1', 'ACTL10', 'ACTR2', 'ADAM21', 'ADAT2']...
#   NCBI654: 664개 누락 — ['ABCB10', 'ACSM2A', 'ACSM2B', 'ACTA1', 'ACTBL2', 'ACTG1', 'ACTL10', 'ACTR2', 'ADAM21', 'ADAT2']...
#   NCBI653: 664개 누락 — ['ABCB10', 'ACSM2A', 'ACSM2B', 'ACTA1', 'ACTBL2', 'ACTG1', 'ACTL10', 'ACTR2', 'ADAM21', 'ADAT2']...
#   TENX185: 656개 누락 — ['A1BG', 'ABCC10', 'ABCC6', 'ABHD17A', 'ACER2', 'ACOT2', 'ACPP', 'ACR', 'ACRBP', 'ACTR3C']...
#   TENX184: 656개 누락 — ['A1BG', 'ABCC10', 'ABCC6', 'ABHD17A', 'ACER2', 'ACOT2', 'ACPP', 'ACR', 'ACRBP', 'ACTR3C']...
#   TENX178: 656개 누락 — ['A1BG', 'ABCC10', 'ABCC6', 'ABHD17A', 'ACER2', 'ACOT2', 'ACPP', 'ACR', 'ACRBP', 'ACTR3C']...
#   TENX174: 656개 누락 — ['A1BG', 'ABCC10', 'ABCC6', 'ABHD17A', 'ACER2', 'ACOT2', 'ACPP', 'ACR', 'ACRBP', 'ACTR3C']...
#   MISC33: 654개 누락 — ['A4GNT', 'AADACL2', 'ACCSL', 'ACOD1', 'ACP7', 'ACSM2A', 'ACSM4', 'ACTL7A', 'ACTL7B', 'ACTRT2']...
#   MISC50: 611개 누락 — ['AANAT', 'ACP4', 'ACP7', 'ACSM2A', 'ACTL7A', 'ACTL7B', 'ACTL9', 'ADGRD2', 'ADGRG4', 'ADH1A']...
#   TENX180: 522개 누락 — ['A1BG', 'ABCC10', 'ABCC6', 'ABHD17A', 'ACER2', 'ACOT2', 'ACR', 'ACRBP', 'ACTR3C', 'ADCK1']...
#   TENX173: 522개 누락 — ['A1BG', 'ABCC10', 'ABCC6', 'ABHD17A', 'ACER2', 'ACOT2', 'ACR', 'ACRBP', 'ACTR3C', 'ADCK1']...
#   TENX172: 522개 누락 — ['A1BG', 'ABCC10', 'ABCC6', 'ABHD17A', 'ACER2', 'ACOT2', 'ACR', 'ACRBP', 'ACTR3C', 'ADCK1']...
#   TENX171: 522개 누락 — ['A1BG', 'ABCC10', 'ABCC6', 'ABHD17A', 'ACER2', 'ACOT2', 'ACR', 'ACRBP', 'ACTR3C', 'ADCK1']...
#   TENX170: 522개 누락 — ['A1BG', 'ABCC10', 'ABCC6', 'ABHD17A', 'ACER2', 'ACOT2', 'ACR', 'ACRBP', 'ACTR3C', 'ADCK1']...
#   TENX169: 522개 누락 — ['A1BG', 'ABCC10', 'ABCC6', 'ABHD17A', 'ACER2', 'ACOT2', 'ACR', 'ACRBP', 'ACTR3C', 'ADCK1']...
#   TENX168: 522개 누락 — ['A1BG', 'ABCC10', 'ABCC6', 'ABHD17A', 'ACER2', 'ACOT2', 'ACR', 'ACRBP', 'ACTR3C', 'ADCK1']...
#   TENX164: 522개 누락 — ['A1BG', 'ABCC10', 'ABCC6', 'ABHD17A', 'ACER2', 'ACOT2', 'ACR', 'ACRBP', 'ACTR3C', 'ADCK1']...
#   TENX163: 522개 누락 — ['A1BG', 'ABCC10', 'ABCC6', 'ABHD17A', 'ACER2', 'ACOT2', 'ACR', 'ACRBP', 'ACTR3C', 'ADCK1']...
#   TENX162: 522개 누락 — ['A1BG', 'ABCC10', 'ABCC6', 'ABHD17A', 'ACER2', 'ACOT2', 'ACR', 'ACRBP', 'ACTR3C', 'ADCK1']...
#   TENX161: 522개 누락 — ['A1BG', 'ABCC10', 'ABCC6', 'ABHD17A', 'ACER2', 'ACOT2', 'ACR', 'ACRBP', 'ACTR3C', 'ADCK1']...
#   TENX156: 522개 누락 — ['A1BG', 'ABCC10', 'ABCC6', 'ABHD17A', 'ACER2', 'ACOT2', 'ACR', 'ACRBP', 'ACTR3C', 'ADCK1']...
#   TENX155: 522개 누락 — ['A1BG', 'ABCC10', 'ABCC6', 'ABHD17A', 'ACER2', 'ACOT2', 'ACR', 'ACRBP', 'ACTR3C', 'ADCK1']...
#   TENX154: 522개 누락 — ['A1BG', 'ABCC10', 'ABCC6', 'ABHD17A', 'ACER2', 'ACOT2', 'ACR', 'ACRBP', 'ACTR3C', 'ADCK1']...
#   TENX153: 522개 누락 — ['A1BG', 'ABCC10', 'ABCC6', 'ABHD17A', 'ACER2', 'ACOT2', 'ACR', 'ACRBP', 'ACTR3C', 'ADCK1']...
#   TENX144: 522개 누락 — ['A1BG', 'ABCC10', 'ABCC6', 'ABHD17A', 'ACER2', 'ACOT2', 'ACR', 'ACRBP', 'ACTR3C', 'ADCK1']...
#   TENX128: 522개 누락 — ['A1BG', 'ABCC10', 'ABCC6', 'ABHD17A', 'ACER2', 'ACOT2', 'ACR', 'ACRBP', 'ACTR3C', 'ADCK1']...
#   TENX152: 520개 누락 — ['A1BG', 'ABCC10', 'ABCC6', 'ABHD17A', 'ACER2', 'ACOT2', 'ACR', 'ACRBP', 'ACTR3C', 'ADCK1']...
#   TENX92: 520개 누락 — ['A1BG', 'ABCC10', 'ABCC6', 'ABHD17A', 'ACER2', 'ACOT2', 'ACR', 'ACRBP', 'ACTR3C', 'ADCK1']...
#   TENX91: 520개 누락 — ['A1BG', 'ABCC10', 'ABCC6', 'ABHD17A', 'ACER2', 'ACOT2', 'ACR', 'ACRBP', 'ACTR3C', 'ADCK1']...
#   TENX90: 520개 누락 — ['A1BG', 'ABCC10', 'ABCC6', 'ABHD17A', 'ACER2', 'ACOT2', 'ACR', 'ACRBP', 'ACTR3C', 'ADCK1']...
#   TENX89: 520개 누락 — ['A1BG', 'ABCC10', 'ABCC6', 'ABHD17A', 'ACER2', 'ACOT2', 'ACR', 'ACRBP', 'ACTR3C', 'ADCK1']...
#   TENX73: 520개 누락 — ['A1BG', 'ABCC10', 'ABCC6', 'ABHD17A', 'ACER2', 'ACOT2', 'ACR', 'ACRBP', 'ACTR3C', 'ADCK1']...
#   TENX72: 520개 누락 — ['A1BG', 'ABCC10', 'ABCC6', 'ABHD17A', 'ACER2', 'ACOT2', 'ACR', 'ACRBP', 'ACTR3C', 'ADCK1']...
#   TENX71: 520개 누락 — ['A1BG', 'ABCC10', 'ABCC6', 'ABHD17A', 'ACER2', 'ACOT2', 'ACR', 'ACRBP', 'ACTR3C', 'ADCK1']...
#   TENX70: 520개 누락 — ['A1BG', 'ABCC10', 'ABCC6', 'ABHD17A', 'ACER2', 'ACOT2', 'ACR', 'ACRBP', 'ACTR3C', 'ADCK1']...
#   TENX68: 520개 누락 — ['A1BG', 'ABCC10', 'ABCC6', 'ABHD17A', 'ACER2', 'ACOT2', 'ACR', 'ACRBP', 'ACTR3C', 'ADCK1']...
#   TENX65: 520개 누락 — ['A1BG', 'ABCC10', 'ABCC6', 'ABHD17A', 'ACER2', 'ACOT2', 'ACR', 'ACRBP', 'ACTR3C', 'ADCK1']...
#   TENX62: 520개 누락 — ['A1BG', 'ABCC10', 'ABCC6', 'ABHD17A', 'ACER2', 'ACOT2', 'ACR', 'ACRBP', 'ACTR3C', 'ADCK1']...
#   NCBI776: 520개 누락 — ['A1BG', 'ABCC10', 'ABCC6', 'ABHD17A', 'ACER2', 'ACOT2', 'ACR', 'ACRBP', 'ACTR3C', 'ADCK1']...
#   MISC73: 344개 누락 — ['ABCA10', 'ABCG8', 'ADAM2', 'ADCY8', 'ADGRA1', 'ADGRG2', 'ADGRV1', 'AGXT', 'AHSP', 'AKR1C4']...
#   MISC35: 344개 누락 — ['ABHD16B', 'ACOD1', 'ACP7', 'ACSM2B', 'ACTL7B', 'ACTRT2', 'ADAMTS20', 'AKR1B15', 'AKR1C4', 'ALX3']...
#   MISC48: 312개 누락 — ['ABCG8', 'ACP7', 'ACSM5', 'ACTL6B', 'ACTRT2', 'ADAM2', 'ADH1A', 'AIPL1', 'AKR1C4', 'ALOX15B']...
#   MISC43: 311개 누락 — ['AARD', 'ABCG8', 'ACER1', 'ACP7', 'ACSM4', 'ACSM5', 'ACTL7A', 'ACTL9', 'ADAM2', 'ADH1A']...
#   MISC70: 304개 누락 — ['ABCG8', 'ACP7', 'ACTL7A', 'ADAM2', 'ADGRV1', 'ADH1A', 'AGXT', 'AKR1B15', 'AKR1C4', 'ALG1L2']...
#   MISC36: 294개 누락 — ['ACTL7A', 'ACTL9', 'ADAM2', 'ADH1A', 'AKR1C4', 'ALLC', 'ALOX15B', 'AMELY', 'ANKRD30A', 'ARSH']...
#   MISC57: 253개 누락 — ['ACP7', 'ACSM4', 'ACTL7B', 'ACTL9', 'ACTRT2', 'ADAM2', 'ADCYAP1R1', 'ADH1A', 'AGXT', 'AKR1C4']...
#   MISC55: 248개 누락 — ['AARD', 'ABCG8', 'ACP7', 'ACSM5', 'ADAM2', 'ADH1A', 'AGXT', 'AKR1C4', 'ALG1L2', 'ALOX15B']...
#   MISC51: 247개 누락 — ['A3GALT2', 'ABCC12', 'ABCG8', 'ACP4', 'ACP7', 'ADCY8', 'ADH1A', 'AKNAD1', 'AKR1C4', 'ALOX15B']...
#   MISC41: 188개 누락 — ['ACOT1', 'ACTL7A', 'AKAP4', 'AKR1C4', 'ALX4', 'AQP2', 'ARSF', 'ARSH', 'ASB5', 'ASCL4']...
#   MISC39: 188개 누락 — ['ACP7', 'ACSM2A', 'ACTL6B', 'ADAM2', 'ADGRA1', 'ADGRD2', 'ADH1A', 'AKR1C4', 'ALX1', 'AMELY']...
#   MISC71: 183개 누락 — ['ADAM2', 'ADGRV1', 'ADH1A', 'AKR1C4', 'ALG1L2', 'ALOX15B', 'AMELY', 'ANKK1', 'APOH', 'ARHGAP36']...
#   MISC58: 182개 누락 — ['ABCG8', 'ABHD16B', 'ACOD1', 'ACSM5', 'ACTRT1', 'ADH1A', 'AKR1C4', 'AMELY', 'ANKK1', 'ARSH']...
#   TENX183: 179개 누락 — ['ACPP', 'ADGRF2', 'ADPRHL2', 'ALG1L', 'ARMC4', 'ARNTL', 'ARNTL2', 'ATP5MD', 'ATP5MPL', 'ATP6AP1L']...
#   TENX182: 179개 누락 — ['ACPP', 'ADGRF2', 'ADPRHL2', 'ALG1L', 'ARMC4', 'ARNTL', 'ARNTL2', 'ATP5MD', 'ATP5MPL', 'ATP6AP1L']...
#   TENX179: 179개 누락 — ['ACPP', 'ADGRF2', 'ADPRHL2', 'ALG1L', 'ARMC4', 'ARNTL', 'ARNTL2', 'ATP5MD', 'ATP5MPL', 'ATP6AP1L']...
#   TENX177: 179개 누락 — ['ACPP', 'ADGRF2', 'ADPRHL2', 'ALG1L', 'ARMC4', 'ARNTL', 'ARNTL2', 'ATP5MD', 'ATP5MPL', 'ATP6AP1L']...
#   MISC60: 178개 누락 — ['ACP7', 'ADAM2', 'ADH1A', 'AKR1C4', 'ALDH1A2', 'ALG1L2', 'ALKAL1', 'ALOX15B', 'ALOXE3', 'AMELY']...
#   MISC69: 175개 누락 — ['ABCG8', 'ACP7', 'ACSM5', 'ADAM2', 'ADAM23', 'ADH1A', 'AGXT', 'AKR1C4', 'ALG1L2', 'ALOX15B']...
#   NCBI595: 175개 누락 — ['ERV3-1', 'ERVFRD-1', 'ERVK3-1', 'ERVMER34-1', 'ERVV-1', 'ERVV-2', 'ERVW-1', 'HLA-A', 'HLA-C', 'HLA-DMA']...
#   NCBI594: 175개 누락 — ['ERV3-1', 'ERVFRD-1', 'ERVK3-1', 'ERVMER34-1', 'ERVV-1', 'ERVV-2', 'ERVW-1', 'HLA-A', 'HLA-C', 'HLA-DMA']...
#   NCBI593: 175개 누락 — ['ERV3-1', 'ERVFRD-1', 'ERVK3-1', 'ERVMER34-1', 'ERVV-1', 'ERVV-2', 'ERVW-1', 'HLA-A', 'HLA-C', 'HLA-DMA']...
#   NCBI592: 175개 누락 — ['ERV3-1', 'ERVFRD-1', 'ERVK3-1', 'ERVMER34-1', 'ERVV-1', 'ERVV-2', 'ERVW-1', 'HLA-A', 'HLA-C', 'HLA-DMA']...
#   NCBI591: 175개 누락 — ['ERV3-1', 'ERVFRD-1', 'ERVK3-1', 'ERVMER34-1', 'ERVV-1', 'ERVV-2', 'ERVW-1', 'HLA-A', 'HLA-C', 'HLA-DMA']...
#   MISC45: 167개 누락 — ['ABCG8', 'ADAM2', 'ADH1A', 'AKR1C4', 'ALPP', 'AMELY', 'APOH', 'ARSH', 'ATCAY', 'ATP2B3']...
#   MISC54: 159개 누락 — ['ACP7', 'ADAM2', 'ADH1A', 'AGXT', 'AKR1C4', 'ALG1L2', 'ALOX15B', 'ALOXE3', 'AMELY', 'ANKK1']...
#   MISC34: 156개 누락 — ['ACP4', 'ACP7', 'ACTL9', 'ADAM2', 'ADCY8', 'ADH1A', 'AKR1C4', 'ALOX15B', 'ALOXE3', 'AMELY']...
#   MISC52: 155개 누락 — ['AARD', 'ABCG8', 'ACCSL', 'ACP7', 'ADAM2', 'ADH1A', 'AKR1C4', 'ALG1L', 'ALG1L2', 'ALOX15B']...
#   MISC42: 142개 누락 — ['ABCG8', 'ACP7', 'ADH1A', 'AKR1C4', 'ALOX15B', 'ALOXE3', 'ANGPT4', 'ANKK1', 'ANKRD30B', 'APOH']...
#   MISC59: 139개 누락 — ['ACP7', 'ADAM2', 'ADH1A', 'AGXT', 'AKR1C4', 'ALOX15B', 'ALOXE3', 'AMELY', 'ANKK1', 'ARSH']...
#   MISC53: 131개 누락 — ['ACOT1', 'ACSM5', 'ADAM2', 'ADH1A', 'AGXT', 'AKR1C4', 'ALAS2', 'ALOX15B', 'ALOXE3', 'ANKK1']...
#   MISC72: 125개 누락 — ['ABCG8', 'ACTL7A', 'ACTRT2', 'ADAM2', 'ADGRV1', 'ADH1A', 'AKR1C4', 'ALOX15B', 'AMELY', 'ANKK1']...
#   MISC47: 112개 누락 — ['ABCG8', 'ACP4', 'ADH1A', 'AKR1C4', 'ANKK1', 'APOH', 'ARSH', 'ATP8A2', 'BHLHA9', 'BPIFA3']...
#   MISC56: 111개 누락 — ['ABCG8', 'ACSM5', 'ADH1A', 'AGXT', 'AKR1C4', 'ALOX15B', 'ALOXE3', 'ANKK1', 'APOH', 'ARSH']...
#   MISC46: 107개 누락 — ['ABCG8', 'ACP7', 'ACTL7A', 'ADH1A', 'AKR1C4', 'AMELY', 'APOH', 'ARSH', 'ATCAY', 'ATP2B3']...
#   MISC63: 105개 누락 — ['ACP7', 'ACTL7A', 'ACTRT2', 'ADAM2', 'AIPL1', 'AMELY', 'BPIFA3', 'CABP2', 'CALML5', 'CCDC172']...
#   MISC49: 102개 누락 — ['ADAM2', 'ADH1A', 'AKR1C4', 'ALOXE3', 'AMELY', 'AQP10', 'ARSH', 'BPIFA3', 'BPIFB3', 'BPIFB6']...
#   MISC61: 95개 누락 — ['ADAM2', 'ADH1A', 'AGXT', 'AKR1C4', 'ALG1L2', 'ALOX15B', 'ALOXE3', 'AMELY', 'ANKK1', 'APOH']...
#   MISC66: 94개 누락 — ['ABCG8', 'ADAM2', 'AGXT', 'AKR1C4', 'AMELY', 'ASB5', 'ATCAY', 'BPIFA3', 'BPIFB3', 'BPIFB6']...
#   MISC40: 90개 누락 — ['ACTL7B', 'ADH1A', 'AKR1C4', 'ALOX15B', 'AMELY', 'ATCAY', 'BPIFA3', 'BPIFB3', 'CABP2', 'CACNA1G']...
#   MISC68: 89개 누락 — ['ABCG8', 'ACP7', 'ACSM5', 'ADAM2', 'ADH1A', 'AGXT', 'AKR1C4', 'APOH', 'ARSH', 'ATCAY']...
#   MISC38: 83개 누락 — ['AARD', 'ADAM2', 'ADH1A', 'AGXT', 'AKR1C4', 'ARSH', 'BPIFA3', 'BPIFB3', 'BPIFB6', 'CABP2']...
#   MISC67: 60개 누락 — ['ADAM2', 'AGXT', 'AKR1C4', 'AMELY', 'ASB10', 'ASB5', 'ATCAY', 'BHLHA9', 'BPIFA3', 'BPIFB3']...
#   MISC37: 58개 누락 — ['ADAM2', 'AKR1C4', 'ALOX15B', 'ARSH', 'BPIFA3', 'BPIFB3', 'BPIFB6', 'BTNL3', 'CABP2', 'CCDC27']...
#   MISC65: 57개 누락 — ['ADAM2', 'ADH1A', 'AKR1C4', 'ALOX15B', 'ARSH', 'ATCAY', 'BPIFA3', 'BPIFB3', 'BPIFB6', 'CABP2']...
#   MISC62: 56개 누락 — ['ACP7', 'ADAM2', 'ADH1A', 'AKR1C4', 'AMELY', 'BPIFA3', 'BPIFB3', 'BPIFB6', 'CABP2', 'CCDC27']...
#   MISC64: 50개 누락 — ['ADAM2', 'ADH1A', 'AKR1C4', 'ALOX15B', 'ARSH', 'BPIFA3', 'BPIFB3', 'BPIFB6', 'CABP2', 'CCDC27']...
#   NCBI572: 18개 누락 — ['ACPP', 'ADPRHL2', 'CDR1', 'CLLU1OS', 'ELMSAN1', 'FAM169B', 'FAM49A', 'FAM49B', 'GDF5OS', 'GVQW2']...
#   NCBI571: 18개 누락 — ['ACPP', 'ADPRHL2', 'CDR1', 'CLLU1OS', 'ELMSAN1', 'FAM169B', 'FAM49A', 'FAM49B', 'GDF5OS', 'GVQW2']...
#   NCBI570: 18개 누락 — ['ACPP', 'ADPRHL2', 'CDR1', 'CLLU1OS', 'ELMSAN1', 'FAM169B', 'FAM49A', 'FAM49B', 'GDF5OS', 'GVQW2']...
#   NCBI569: 18개 누락 — ['ACPP', 'ADPRHL2', 'CDR1', 'CLLU1OS', 'ELMSAN1', 'FAM169B', 'FAM49A', 'FAM49B', 'GDF5OS', 'GVQW2']...
#   NCBI4: 18개 누락 — ['ACPP', 'ADPRHL2', 'CDR1', 'CLLU1OS', 'ELMSAN1', 'FAM169B', 'FAM49A', 'FAM49B', 'GDF5OS', 'GVQW2']...
#   NCBI3: 18개 누락 — ['ACPP', 'ADPRHL2', 'CDR1', 'CLLU1OS', 'ELMSAN1', 'FAM169B', 'FAM49A', 'FAM49B', 'GDF5OS', 'GVQW2']...
#   NCBI2: 18개 누락 — ['ACPP', 'ADPRHL2', 'CDR1', 'CLLU1OS', 'ELMSAN1', 'FAM169B', 'FAM49A', 'FAM49B', 'GDF5OS', 'GVQW2']...
#   NCBI1: 18개 누락 — ['ACPP', 'ADPRHL2', 'CDR1', 'CLLU1OS', 'ELMSAN1', 'FAM169B', 'FAM49A', 'FAM49B', 'GDF5OS', 'GVQW2']...

# %%
# ===== 5. 누락 슬라이드의 missing gene 제거 + CSV 저장 =====

# 누락 슬라이드들이 빠뜨린 gene 모두 수집
genes_to_remove = set()
for sid, n_miss, miss_list in dropped_slides:
    genes_to_remove.update(miss_list)

print(f'누락 슬라이드에서 빠진 gene 수: {len(genes_to_remove)}')
print(f'제거 전 common_genes: {len(common_genes):,}')

# common_genes에서 제거
common_genes -= genes_to_remove
common_genes_sorted = sorted(common_genes)

print(f'제거 후 common_genes: {len(common_genes):,}')

# CSV 저장
save_csv_path = f'{save_base}/visium_common_genes.csv'
df_genes = pd.DataFrame({
    'gene': common_genes_sorted,
    'coverage': [gene_counter[g] for g in common_genes_sorted],
    'coverage_pct': [gene_counter[g] / n_slides * 100 for g in common_genes_sorted],
})
df_genes.to_csv(save_csv_path, index=False)
print(f'\nCSV 저장 완료: {save_csv_path}')
print(f'총 {len(df_genes)} genes')
print(df_genes.head(10))
# Out:
# 누락 슬라이드에서 빠진 gene 수: 3510
# 제거 전 common_genes: 17,928
# 제거 후 common_genes: 14,418
#
# CSV 저장 완료: ../../data/visium_marker_gene_spatial_expression/visium_common_genes.csv
# 총 14418 genes
#       gene  coverage  coverage_pct
# 0     A1CF       385         100.0
# 1      A2M       385         100.0
# 2   A4GALT       385         100.0
# 3     AAAS       385         100.0
# 4     AACS       385         100.0
# 5    AADAC       385         100.0
# 6  AADACL3       385         100.0
# 7  AADACL4       385         100.0
# 8    AADAT       385         100.0
# 9    AAGAB       385         100.0
